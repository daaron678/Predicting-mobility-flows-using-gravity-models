# %% [markdown]
# - When using the Arcpy module and others provided by ArcGIS Pro, within a stand-alone script, certain conditions must be set within the ArcGIS Pro app. See the section "Authorize Python outside the application", at the bottom of the doc page:
# >https://pro.arcgis.com/en/pro-app/3.6/arcpy/get-started/installing-python-for-arcgis-pro.htm#ESRI_SECTION1_E66058ADDA284EE19A5160207A935F6F
#
# - ArcGIS Pro provides a default conda environment containing the arcpy package and other python libraries. The python executable within this environment is typically located at: 'C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3'. The docs below recommend cloning the environment instead of installing or upgrading packages within the default provided environment (see 'Cloning an Environment' within ArcGIS Pro) I set the clone destination to where my other conda envs are located : ~anaconda3/envs.
# >https://pro.arcgis.com/en/pro-app/3.6/arcpy/get-started/what-is-conda.htm
#
# - This script can be executed on the command line by calling the batch file provided by ArcGIS Pro using the command'c:\ArcGIS\Pro\bin\Python\scripts\propy.bat analysis.ipynb'. Running the script by calling the batch file ensures you have the same set of packages that you are using in the ArcGIS Pro app.
# >https://pro.arcgis.com/en/pro-app/3.6/arcpy/get-started/using-conda-with-arcgis-pro.htm

# %%
# this gave an error, so I instead set my environment to the default arcgispro-py3 environment 
# !conda create --clone "C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3" --name arcMob

# %%
from 'clean.ipynb' import fl_tess_cleaned
