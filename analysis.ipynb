# %% [markdown]
# A python script can be run interactively within ArcGIS Pro (via Python window or ArcGIS Notebooks), or within an IDE such as VS Code. To use ArcGIS Pro's default python environment (arcgispro-py3), the environment can be set in the IDE, or a cloned environment can be set. For me, the arcgispro-py3 environment is located at: 'C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3'.
# >https://doc.esri.com/en/arcgis-pro/latest/arcpy/get-started/installing-python-for-arcgis-pro.html

# %% [markdown]
# ESRI recommends using a cloned environment of arcgispro-py3 if the environment is modified by adding or removing packages.
# >https://pro.arcgis.com/en/pro-app/3.6/arcpy/get-started/what-is-conda.htm
#
# - I copied the arcgispro-py3 directory, named it 'arcgispro-copy' and moved it to the directory with the rest of my conda envs located at: 'C:/Users/[my_name]/anaconda3/envs'.

# %% [markdown]
# The script can be run interactively within the ArcGIS Pro application and as a standalone script via a command-line call. ESRI provides directions for running a standalone script:
# >https://doc.esri.com/en/arcgis-pro/latest/arcpy/get-started/using-conda-with-arcgis-pro.html
# - Within the ArcGIS Pro installation are batch files to run the script in the default environment. Using the 'propy' batch file at "C:\Program Files\ArcGIS\Pro\bin\Python\Scripts\propy.bat" uses the same set of packages that are in use in the ArcGIS Pro app. This script can be run as a standalone script using:

# %%
# !"C:/Program Files/ArcGIS/Pro/bin/Python/Scripts/propy.bat"
# Out:
# ^C

# %%
# !conda install anaconda::dropbox
# !conda install -c conda-forge::scikit-mobility
# !conda install conda-forge::python-dotenv
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
#  - anaconda
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\dylan\anaconda3\envs\arcgispro_copy
#
#   added / updated specs:
#     - anaconda::dropbox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2026.7.22          |  py311haa95532_0         135 KB
#     dropbox-12.2.0             |  py311haa95532_0         1.6 MB  anaconda
#     ply-3.11                   |  py311haa95532_0         111 KB
#     stone-3.5.2                |  py311haa95532_0         423 KB
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   dropbox            anaconda/win-64::dropbox-12.2.0-py311haa95532_0
# ...

# %%
from clean.ipynb import fl_tess_cleaned
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from clean.ipynb import fl_tess_cleaned
#
# File c:\Users\dylan\Documents\Projects\mobility flows\Predicting-mobility-flows-using-gravity-models\clean.py:5
#       3 from dropbox import DropboxOAuth2FlowNoRedirect
#       4 import os
# ----> 5 from dotenv import load_dotenv
#       6 from io import BytesIO
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
import os
path = "c:\\Users\\dylan\\Documents\\Projects\\mobility flows\\Predicting-mobility-flows-using-gravity-models"
print(os.path.exists(path))
# Out:
# True
