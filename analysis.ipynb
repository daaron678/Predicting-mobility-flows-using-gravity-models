# %% [markdown]
# Use the ArcGIS Pro environment with included ArcGIS Pro packages:
# > https://pro.arcgis.com/en/pro-app/3.6/arcpy/get-started/installing-python-for-arcgis-pro.htm
# - My python executable is located at
# 'C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3'

# %%
from 'clean.ipynb' import fl_tess_cleaned
